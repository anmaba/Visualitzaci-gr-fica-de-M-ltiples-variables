# %% [markdown]
# # S03 T02: Visualització gràfica de Múltiples variables
#
# Descripció:
# Anem a practicar i a familiaritzar-nos amb la Visualització gràfica de Múltiples variables.
#
# ## NIVELL 1
# ### Exercici 1: Realitza la pràctica del notebook a GitHub "03 EXAMINING DATA" amb seaborn i el dataset "tips".

# %% [markdown]
# Cridem a les llibreries que necessitem i importem el dataset "tips"

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <font size="5"><center><G><u>Fonaments estadístics per a la ciència de dades</u></b></center></font>
#
# \begin{align*}ANNA\:MASÓ\end{align*}
#
# \begin{align*}Maig\:2022\end{align*}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# Fem una mica de lectura i anàlisi estadístic bàsic per conèixer una mica el dataset i començar a treballar amb ell

# %%
# La mida del dataset

tips.shape
# Out:
# (244, 7)

# %%
# El nom de les columnes

tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# Tipus de dades que trobem a cada columna

tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
# Analitzem si hi ha nuls i on són

print(tips.isnull())

print("____________________________________________________________________________")

print(tips.count())

print("____________________________________________________________________________")

print(tips.isnull().sum())

# No hi ha cap nul, per tant no cal fer res més
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]
# ____________________________________________________________________________
# total_bill    244
# tip           244
# sex           244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64
# ____________________________________________________________________________
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
# Imprimim la descripció dels càlculs que ens fa l'operació describe() sobre les columnes que són numèriques

tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# <div class="alert alert- alert-info">
#
# ***
#   \begin{align*}SCATTERPLOT\end{align*}
#
#
# ***

# %% [markdown]
# Creo un gràfic <span style=color:red>Scatterplot</span> que em permet comparar dues variables numèriques, en aquest cas he escollit veure quina relació hi ha entre el total de la factura i les propines (durant tot el notebook deduiré que els valors de les factures i propines són en euros,€)

# %%
# Seguint l'exemple de "Examining Data" faig servir el matplotlib

x = tips.total_bill
y = tips.tip
colors = "Green"
area = 6*6 #canvia la mida dels punts
plt.figure(figsize=(10, 6)) #canviar tamany figura

plt.scatter(
           x,
           y,
           s = area,
           c = colors,
           marker='o',
           alpha=0.5, #transparència dels punts
           edgecolors = "black");

plt.title("Relació entre el total de la factura i les propines donades", fontsize=16)
plt.ylabel("Propines (€)")
plt.xlabel("Total factura (€)")
# Out:
# Text(0.5, 0, 'Total factura (€)')

# %% [markdown]
# Creo un altre gràfic <span style=color:red>Scatterplot</span> que em permet comparar, en aquest cas, les propines i el tamany (entenc que el tamany és els número de persones que hi havia a la taula).

# %%
print(tips.size.size)
print(tips.tip.size)
print(tips.size.shape)
print(tips.tip.shape)
# Out:
# 1
# 244
# ()
# (244,)

# %%
'''
x = tips.tip
y = tips.size
colors = "Green"
area = 6*6 #canvia la mida dels punts
plt.figure(figsize=(10, 10)) #canviar tamany figura

plt.scatter(
           x=x,
           y=y,
           s = area,
           c = colors,
           marker='o',
           alpha=0.5, #transparència dels punts
           edgecolors = "black");

plt.title("Relació entre les persones que han menjat i les propines que han donat")
plt.ylabel("Propines (€)")
plt.xlabel("Número de persones")



plt.show()
'''
# Out:
# '\nx = tips.tip\ny = tips.size\ncolors = "Green"\narea = 6*6 #canvia la mida dels punts\nplt.figure(figsize=(10, 10)) #canviar tamany figura\n\nplt.scatter(\n           x=x,\n           y=y,\n           s = area,\n           c = colors,\n           marker=\'o\',\n           alpha=0.5, #transparència dels punts\n           edgecolors = "black");\n\nplt.title("Relació entre les persones que han menjat i les propines que han donat")\nplt.ylabel("Propines (€)")\nplt.xlabel("Número de persones")\n\n\n\nplt.show()\n'

# %% [markdown]
# <div class="alert alert- alert-info">
#
# ***
#   \begin{align*}PIE\end{align*}
#
#
# ***

# %% [markdown]
# Repeteixo el procediment anterior per comparar si la quantitat de propines té a veure amb el dia de la setmana. Al ser una variable numèrica i una variable categòrica, decideixo utilitzar un <span style=color:red>Pie</span>

# %% [markdown]
# Abans però, vull saber quantes propines s'aconsegueixen cada dia de la setmana, per això primer imprimeixo quants dies de la setmana hi ha i després faig la següent fórmula per crear el dataset que em permetrà fer la figura

# %%
tips.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sumSun = float(tips.loc[tips["day"] == "Sun",["tip"]].sum())
print ("Els diumenges s'han aconseguit" , sumSun , "€ en propines")

sumSat = float(tips.loc[tips["day"] == "Sat",["tip"]].sum())
print ("Els dissabtes s'han aconseguit" , sumSat , "€ en propines")

sumFri = float(tips.loc[tips["day"] == "Fri",["tip"]].sum())
print ("Els divendres s'han aconseguit" , sumFri , "€ en propines")

sumThur = float(tips.loc[tips["day"] == "Thur",["tip"]].sum())
print ("Els dijous s'han aconseguit" , sumThur , "€ en propines")


totalTips = sumThur+sumFri+sumSat+sumSun
print(totalTips)

sumTotTips = tips["tip"].sum()
print(sumTotTips)

# Al ser novata, faig comprovacions per veure que estic fent bé les fòrmules
# Out:
# Els diumenges s'han aconseguit 247.39000000000001 € en propines
# Els dissabtes s'han aconseguit 260.4 € en propines
# Els divendres s'han aconseguit 51.959999999999994 € en propines
# Els dijous s'han aconseguit 171.82999999999996 € en propines
# 731.5799999999999
# 731.5799999999999

# %%
# Creo el mini dataframe amb el que vull treballar

dades = [
    {sumSun},
    {sumSat},
    {sumFri},
    {sumThur}
]

dfDayTips = pd.DataFrame(dades)

# Canvio el nom de les files i de la columna

dfDayTips.rename(index={0:"Sunday",1:"Saturday", 2:"Friday", 3:"Thursday"}, inplace=True)
dfDayTips.columns = ["Tips"]

print(dfDayTips)
# Out:
#             Tips
# Sunday    247.39
# Saturday  260.40
# Friday     51.96
# Thursday  171.83

# %%
# Ara si, procedeixo a crear la figura

dies = (dfDayTips.index[dfDayTips["Tips"] > 0].tolist()) #ho he fet perquè se m'imprmeixin els noms de l'índex sols
plt.figure(figsize=(8,8))


plt.pie(
    data = dfDayTips,
    x = "Tips",
    labels = dies,
    labeldistance=1.15,
    autopct="%0.1f %%", #serveix perquè es faci el percentatge automàtic sobre el gràfic
    wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' })

plt.title("Quins dies es guanyen més i menys propines? (en %)", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Quins dies es guanyen més i menys propines? (en %)')

# %% [markdown]
# <div class="alert alert- alert-info">
#
# ***
#   \begin{align*}MATRIX PLOTS\end{align*}
#
#
# ***

# %%
# Comparació gràfica de les tres columnes amb valors numèrics, total-bill, tip i size

sns.set_theme(style="ticks")

sns.pairplot(
    data=tips, 
    diag_kind='hist',
    kind="kde",
    height=4,
    plot_kws={'alpha': 0.5})

# %% [markdown]
# <div class="alert alert- alert-info">
#
# ***
#   \begin{align*}HISTOGRAMS\end{align*}
#
#
# ***

# %% [markdown]
# La diferència bàsica entre Scatterplots i <span style=color:red>Histogrames</span> és que els primers ens marquen punt per punt, o valor per valor, per tant, són molt útils en datasets petits, en canvi, els histogrames, al agrupar els valors en barres, permeten analitzar datasets molts més grans.

# %%
# En aquest histograma volem saber si en aquest restaurant hi van més dones o més homes

sns.set(style="darkgrid")

sns.histplot(data=tips, 
             x="sex")

plt.title("Clients contabilitzats per sexe (home o dona)", fontsize=16)
plt.ylabel("Número de persones")
plt.xlabel("Sexe")
# Out:
# Text(0.5, 0, 'Sexe')

# %%
# En aquest histograma volem saber quants clients són fumadors

sns.set(style="darkgrid")

sns.histplot(data=tips, 
             x="smoker")

plt.title("Número de clients que són fumadors", fontsize=16)
plt.ylabel("Número de persones")
plt.xlabel("Fumadors o no")
# Out:
# Text(0.5, 0, 'Fumadors o no')

# %%
# Per fer un exemple d'histograma de valors numèrics, utilitzarem la columna de les propines

sns.set(style="darkgrid")
plt.figure(figsize=(10, 6)) #canviar tamany figura

sns.histplot(data=tips, 
            x="tip",
            kde=True,
            bins=10,
            color= "orange")

plt.title("Propines que deixen els clients", fontsize=16)
plt.ylabel("Número de persones")
plt.xlabel("Quantitat de propines (€)")
# Out:
# Text(0.5, 0, 'Quantitat de propines (€)')

# %% [markdown]
# <div class="alert alert- alert-info">
#
# ***
#   \begin{align*}MEDIAN \: - \: MEDIANA - MITJANA\end{align*}
#
#
# ***

# %% [markdown]
# La <span style=color:red>Mediana</span> és el número que divideix els valors en 50% per sota i 50% per sobre.
# Quan el dataset és senar, la mediana és exactament el valor del percentil 50, però si el dataset és parell, s'agafen els dos valors més, es fa la seva mitjana i així obtenim la mediana.
#
# La podem veure en el resum que ens fa el codi "describe" o amb una funció pròpia de python.

# %%
# Si imprimim el dataset amb describe(), la mediana correspon a la fila 50%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# Si utilitzem la fòrmula de python, es faria així
mediana = tips.total_bill.median()
print("La mediana de la columna total_bill és", mediana)
# Out:
# La mediana de la columna total_bill és 17.795

# %% [markdown]
# <div class="alert alert- alert-info">
#
# ***
#   \begin{align*}MEAN - MITJANA\end{align*}
#
#
# ***

# %% [markdown]
# La <span style=color:red>Mitjana</span> ens ajuda a saber on és el centre de la distribució dels valors. Per trobar-la, hem de sumar tots els valors i dividir-los per la quantitat de valors.
# Per exemple, si ens fixem en la columa "total_bill", hauriem de sumar tots els totals i dividir-los pel número de tiquets:

# %% [markdown]
# \begin{align*}\bar{x}\:=\:\frac{16.99+10.34\:+\:...\:+\:18.78}{244}\:=\: 19.78\end{align*}

# %%
# Tenim el següent codi que ens permet calcular-la de forma automàtica

mitjana = tips.total_bill.mean()

print("El tiquet mitjà d'aquest restaurant és de ", mitjana, "€" )
# Out:
# El tiquet mitjà d'aquest restaurant és de  19.785942622950824 €

# %% [markdown]
# <div class="alert alert- alert-info">
#
# ***
#   \begin{align*}VARIANÇA \end{align*}
#
#
# ***

# %% [markdown]
# La variança i la desviació estàndard són dues mesures de variabilitat molt importants en la ciència de dades.
#
# La distància d'un valor amb la mitjana del grup de valors és el que es coneix com a <span style=color:red>desviació</span>.
#
# La fòrmula és (agafant com a exemple el primer número de la columna "total_bill" amb la mitjana calculada anteriorment):

# %% [markdown]
# \begin{align*}x_1 − \bar{x} = 16.99 − 19.78 = -2.7959426229508253 \end{align*}

# %%
# Escrit d'una altra forma seria així:

desviacio = (tips.total_bill[0] - mitjana)
print(tips.total_bill[0]) #posició 1 de la columna
print("La desviació és de ", desviacio)
# Out:
# 16.99
# La desviació és de  -2.7959426229508253

# %% [markdown]
# Si agafem la desviació de tots els valors de la columna i els elevem al quadrat, i després en fem la mitjana, tenim com a resultat la <span style=color:red>variança</span>

# %% [markdown]
# \begin{align*}s^2\:=\:\frac{(-2.795)^2 + · · · + (19.78)^2}{244} = 78.928\end{align*}

# %% [markdown]
# Per sort, tenim un mètode de Numpy que ens permet fer aquest càlcul de forma automàtica

# %%
variança = np.var(tips.total_bill)
print("La variança és ",variança)
# Out:
# La variança és  78.92813148851113

# %% [markdown]
# La variança ens permet dues coses:
#     - Fa que els valors siguin més grans que els originals
#     - Elimina qualsevol número negatiu
#
# La variança és aproximadament, la distancia mitjana al quadrat de la mitjana

# %% [markdown]
# <div class="alert alert- alert-info">
#
# ***
#   \begin{align*}DESVIACIÓ  \:\:  ESTÀNDARD\end{align*}
#
#
# ***

# %% [markdown]
# La <span style=color:red>desviació estàndard</span> és un nombre que descriu la distribució dels valors. Si la desviació estàndard és baixa, significa que la majoria dels nombres estan a prop de la mitjana. En canvi, si és alta significa que els valors es distribueixen en un rang més ampli.
#
# La desviació estàndard és l'arrel quadrada de la variança:

# %% [markdown]
# \begin{align*}s = \sqrt{78.928} = 8.88\end{align*}

# %% [markdown]
# I la llibreria de Numpy també ens dóna un codi per a fer el càlcul automàtic:

# %%
desvEstandar = np.std(tips.total_bill)
print("La desviació estandar és ",desvEstandar)
# Out:
# La desviació estandar és  8.88415057777113

# %% [markdown]
# <div class="alert alert- alert-info">
#
# ***
#   \begin{align*}BOX  \:\:  PLOTS\end{align*}
#
#
# ***

# %% [markdown]
# Creació d'una figura <span style=color:red>Box Plot</span>:
# - Dibuixar una línia fosca que representi la mediana
# - Dibuixar un rectangle que representi el 50% dels valors del mig del dataset. La longitud d'aquesta caixa s'anomena rang interquartil (IQR).
# L' <span style=color:red>IQR</span> és una altra mesura de variabilitat i com la desviació estàndard, com més variables siguin les dades, més gran serà l'IQR. Els dos límits del quadre s'anomenen percentil 25 (o primer quartil) i percentil 75 (o tercer quartil). Així doncs, l'IQR és la diferència entre aquests dos quartils, anomenats Q1(primer quartil) i Q3 (tercer quartil)

# %% [markdown]
# $$IQR = Q3 − Q1$$

# %% [markdown]
# - Fora de la caix, s'estenen dues línies que s'anomenen bigotis (whiskers) i el seu abast sempre ha de ser com a màxim de 1,5 vegades l'IQR. Si alguns valors sobrepassen aquesta distància, solen ser puntuals i apareixen com un punt al dibuix. L'objectiu de fer aquests punts en comptes d'allargar els bigotis és detectar i estudiar valors que s'allunyen de forma inusual de la resta de dades, i s'anomenen "outliers"

# %%
# Exemple d'un box plot amb la columna de dades "total_bill"

sns.set(style="whitegrid")
plt.figure(figsize=(6, 10)) #canviar tamany figura
sns.boxplot(data = tips,
                 y= "total_bill",
                 color='green',
                 fliersize=2, # mida dels outliers
                 orient='v', # orientació vertical de la caixa
                 linewidth=2 , # gruix de la línia de la caixa
                 width=0.5) # amplada de la caixa

plt.title("Observem variacions en les dades de les factures", fontsize=16)
plt.ylabel("Preu de la factura (€)")
# Out:
# Text(0, 0.5, 'Preu de la factura (€)')

# %%
# Podem colocar tots els valors de la columna en un stripplot

sns.set(style="whitegrid")
plt.figure(figsize=(6, 10)) #canviar tamany figura

sns.stripplot(data = tips,
              y= "total_bill",
              orient='v', 
              color='darkblue')
# Out:
# <AxesSubplot:ylabel='total_bill'>

# %%
# I si ajuntem el box plot i l'stripplot obtenim el següent:


sns.set(style="whitegrid")
plt.figure(figsize=(6, 10)) #canviar tamany figura
sns.boxplot(data = tips,
                 y= "total_bill",
                 color='green',
                 fliersize=2, # mida dels outliers
                 orient='v', # orientació vertical de la caixa
                 linewidth=2 , # gruix de la línia de la caixa
                 width=0.5) # amplada de la caixa
sns.stripplot(data = tips,
              y= "total_bill",
              orient='v', 
              color='darkblue')

plt.title("Observem variacions en les dades de les factures", fontsize=16)
plt.ylabel("Preu de la factura (€)")
# Out:
# Text(0, 0.5, 'Preu de la factura (€)')

# %% [markdown]
# L'exemple anterior és només utilitzant una variable, però podem fer box plots amb més d'una variable. Per a poder-ho fer, utilitzarem "catplot". Veiem exemples:

# %%
# Dues variables: la categòrica "sex" i la numèrica "tip"

sns.set(style="whitegrid")
sns.catplot(data = tips,
                 x= "sex",
                 y= "total_bill",
                 kind= "box",
                 fliersize=2, # mida dels outliers
                 orient='v', # orientació vertical de la caixa
                 linewidth=2 , # gruix de la línia de la caixa
                 width=0.5) # amplada de la caixa
sns.stripplot(data = tips,
              x= "sex",
              y= "total_bill",
              orient='v', 
              color='darkblue',
              alpha = 0.4)

plt.title("Relació entre el sexe del client i les propines", fontsize=16)
plt.ylabel("Propines donades (€)")
plt.xlabel("Sexe del client")
# Out:
# Text(0.5, 8.95999999999998, 'Sexe del client')

# %%
# Tres variables: dues categòriques ("sex" i "smoker") i una numèrica ("tip")

sns.set(style="whitegrid")
sns.catplot(data = tips,
                 x= "sex",
                 y= "total_bill",
                 hue = "smoker",
                 kind= "box",
                 fliersize=2, # mida dels outliers
                 orient='v', # orientació vertical de la caixa
                 linewidth=2 , # gruix de la línia de la caixa
                 width=0.5) # amplada de la caixa
sns.stripplot(data = tips,
              x= "sex",
              y= "total_bill",
              hue = "smoker",
              orient='v', 
              color='darkblue',
              alpha = 0.4)

plt.title("Relació entre el sexe del client, si és fumador o no i les propines", fontsize=16)
plt.ylabel("Propines donades (€)")
plt.xlabel("Sexe del client")
# Out:
# Text(0.5, 22.960000000000015, 'Sexe del client')

# %%
# Quatre variables: tres categòriques ("sex", "smoker" i "time") i una numèrica ("tip")


sns.set(style="whitegrid")
sns.catplot(data = tips,
                 x= "sex",
                 y= "total_bill",
                 hue = "smoker",
                 col = "time",
                 kind= "box",
                 fliersize=2, # mida dels outliers
                 orient='v', # orientació vertical de la caixa
                 linewidth=2 , # gruix de la línia de la caixa
                 width=0.5) # amplada de la caixa

# %% [markdown]
# ## NIVELL 2
# ### Exercici 2: Repeteix l'exercici 1 amb el dataset que disposem en el repositori de GitHub PRE-PROCESSING-DATA, movies.dat

# %% [markdown]
# ## NIVELL 3
# ### Exercici 3: En aquest exercici no us donarem gaires indicacions perquè volem que ens mostreu la vostra creativitat. Sorprèn-me amb gràfiques i interpretacions del dataset "movies.dat" del exercici anterior.
